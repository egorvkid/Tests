# %%
arr = [1,2,3,1]
arr = [1, 3, 2, 1, 5, 3, 5, 1, 4]
def func(arr):
    d = {i:1 for i in arr}
    return list(d.keys())
func(arr)
# Out:
# [1, 3, 2, 5, 4]

# %% [markdown]
# SELECT department from employees WHERE position='Software Developer' GROUP BY department HAVING COUNT(*)<5

# %%
from IPython.display import Image
Image("test_profi.jpg")
